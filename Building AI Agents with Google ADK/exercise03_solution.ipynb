# %% [markdown]
# # "Greetings, World!": Our first agent

# %% [markdown]
# ### ⚙️ Before we get started - Installing Google ADK
#
# - Ensure the Google ADK library is installed in your DataLab via `pip install google-adk`.
# - Ignore any harmless warnings if the installation completes successfully. ✅

# %%
# !pip install protobuf==5.28.1 google-adk==1.0.0 litellm -q -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# clarifai 10.8.4 requires protobuf==5.27.3, but you have protobuf 5.28.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.30.0 requires opentelemetry-sdk~=1.30.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.30.0 requires opentelemetry-sdk~=1.30.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# opentelemetry-instrumentation 0.51b0 requires opentelemetry-semantic-conventions==0.51b0, but you have opentelemetry-semantic-conventions 0.55b1 which is incompatible.
# opentelemetry-instrumentation-asgi 0.51b0 requires opentelemetry-semantic-conventions==0.51b0, but you have opentelemetry-semantic-conventions 0.55b1 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.51b0 requires opentelemetry-semantic-conventions==0.51b0, but you have opentelemetry-semantic-conventions 0.55b1 which is incompatible.

# %%
import importlib
importlib.invalidate_caches()

# %% [markdown]
# ### 🔐 Configuring API Access
#
# - Set your OpenAI API base as an environment variable when using OpenAI models.

# %%
import os
os.environ["OPENAI_API_BASE"]="http://localhost:11434/v1"

# %% [markdown]
# ### 🧑‍💻 Creating Our First Agent
#
# - Define the agent with:
#   - **name**: unique identifier for logs,
#   - **description**: brief internal summary,
#   - **instruction**: core behavior directive,
#   - **model**: choose your LLM.
# - Run the cell to instantiate and test your first ADK agent! 🎉

# %%
from google.adk.agents import LlmAgent
from google.adk.models.lite_llm import LiteLlm

AGENT_MODEL = LiteLlm(model="openai/gpt-4o-mini")

agent = LlmAgent(
    name="WelcomeAgent",
    description="An agent that welcomes the user.",
    instruction="Always greet the user politely.",
    model=AGENT_MODEL
)

print(f"Agent '{agent.name}' created.")
# Out:
# Agent 'WelcomeAgent' created.
